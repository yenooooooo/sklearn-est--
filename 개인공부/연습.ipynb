# %% [markdown]
# csv 파일 불러오기

# %%
import pandas as pd

df = pd.read_csv("practice_churn.csv")
df.head()
# Out:
#    age  gender  login_days  paid_user  churn
# 0   23    male           3          0      1
# 1   45  female          25          1      0
# 2   31    male          10          0      1
# 3   28  female          20          1      0
# 4   35    male           5          0      1

# %% [markdown]
# 데이터 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         15 non-null     int64
#  1   gender      15 non-null     object
#  2   login_days  15 non-null     int64
#  3   paid_user   15 non-null     int64
#  4   churn       15 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 732.0+ bytes

# %%
df.tail()
# Out:
#     age  gender  login_days  paid_user  churn
# 10   48    male          22          1      0
# 11   33  female          12          0      1
# 12   29    male          16          1      0
# 13   55  female          30          1      0
# 14   24    male           4          0      1

# %% [markdown]
# x,y 분리하기 타겟

# %%
X = df.drop("churn", axis=1)
y = df["churn"]
df
# Out:
#     age  gender  login_days  paid_user  churn
# 0    23    male           3          0      1
# 1    45  female          25          1      0
# 2    31    male          10          0      1
# 3    28  female          20          1      0
# 4    35    male           5          0      1
# 5    52  female          27          1      0
# 6    41    male          15          1      0
# 7    22  female           2          0      1
# 8    39    male          18          1      0
# 9    26  female           7          0      1
# 10   48    male          22          1      0
# 11   33  female          12          0      1
# 12   29    male          16          1      0
# 13   55  female          30          1      0
# 14   24    male           4          0      1

# %%
X = pd.get_dummies(X, columns=["gender"], drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
proba = model.predict_proba(X_test)[:, 1]
proba
# Out:
# array([9.93686285e-01, 5.44783348e-01, 9.99811605e-01, 4.02219683e-08,
#        6.27668790e-07])

# %%
y_pred = (proba >= 0.5).astype(int)
y_pred
# Out:
# array([1, 1, 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 1.0
